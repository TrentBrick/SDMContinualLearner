# %%
import numpy as np
import pandas as pd
import seaborn as sns
from sklearn.preprocessing import minmax_scale
import matplotlib.pyplot as plt
import sys
import warnings
import matplotlib.pyplot as plt
import random
warnings.filterwarnings('ignore')

# %%
def split_data(data, labels, split):
    from collections import Counter
    distinct_labels = list(Counter(labels).keys())
    n_labels = len(distinct_labels)
    n_split = int(n_labels/split)
    trans = data.T
    trans.columns = labels
    datasets = {}
    datalabels = {}
    for i in range(n_split):
        cond1 = trans.columns.values >= i*split
        cond2 = trans.columns.values < (i+1)*split
        out = trans.iloc[:,cond1&cond2]
        out_label = out.columns.values
        datasets[i] = out.T
        datalabels[i] = out_label
    return (datasets, datalabels)

# %%
def generate_transformation_matrix(n_kc,n_orn,n_response,seed):
    R = np.zeros((n_kc, n_orn))
    for i in range(n_kc):
        random.seed(seed+i)
        np.random.seed(seed+i)
        R[i,random.sample(list(range(n_orn)), n_response)] = 1
    return R

def get_KC(p,R,thresh):
    '''
    odor: a vector of ORN responses for a given odor
    w: inhibitory synaptic strength from LN to PN
    R: random linear transformation matrix from PN to KC
    thresh: rectlinear threshold for KC activation
    '''
    KC = np.matmul(R,p)
    KC[KC<=thresh] = 0
    threshold = np.quantile(KC,0.99) # this is the topK operation. keeps 1% active. 
    KC[KC<threshold] = 0
    KC = KC/np.max(KC) # renorm of the KC values here. 
    #KC[KC>0] = 1
    return KC

# %%
def train(data, label, lr, n_class, shift):
    from collections import Counter
    weights = np.zeros([n_class,n_kc])#*10.0
    kcs = np.array([get_KC(np.array(data.iloc[i,:]),R,thresh) for i in range(data.shape[0])])
    distinct_label = np.sort(list(Counter(label).keys()))
    if len(distinct_label) != n_class:
        raise ValueError('Number of classes to be trained does not match!!!')
    for i in range(n_class):
        sum_kc = np.sum(kcs[np.array(label==distinct_label[i])],axis=0)
        weights[distinct_label[i]-shift] += lr*sum_kc
        #weights[weights<0] = 0
        weights[weights>1] = 1
    return weights

# %%
def accu(weights, data, label):
    kcs = [get_KC(np.array(data.iloc[i,:]),R,thresh) for i in range(data.shape[0])]
    kcs = np.array(kcs)
    result = np.matmul(weights, kcs.T)
    pred = np.argmax(result, axis=0)
    return np.sum(pred==label)/len(label)

# %% [markdown]
# train_data = pd.read_csv('./processed_data/cifar100_train_resnet18.csv',header=None)
# train_label = pd.read_csv('./processed_data/cifar100_train_label_resnet18.csv',header=None)
# train_label = [train_label.values[i][0] for i in range(train_label.shape[0])]
# test = pd.read_csv('./processed_data/cifar100_test_resnet18.csv',header=None)
# test_label = pd.read_csv('./processed_data/cifar100_test_label_resnet18.csv',header=None)
# test_label = [test_label.values[i][0] for i in range(test_label.shape[0])]

# %% [markdown]
# train_data = pd.DataFrame(minmax_scale(train_data,axis=1))
# test = pd.DataFrame(minmax_scale(test,axis=1))

# %% [markdown]
# train_datasets, train_labels = split_data(train_data, train_label, 4)
# test_datasets, test_labels = split_data(test, test_label, 4)

# %%
import torch

def load_my_dataset(seed_ind, min_max_scale=True):
    
    train_datasets = dict()
    train_labels = dict()

    test_datasets = dict()
    test_labels = dict()
    
    seed_ind_map = {1:3, 2:15, 3:27 , 4:97}
    
    if seed_ind==0:
        file_suffix = ""
    else: 
        file_suffix = f"_RandSeed_{seed_ind_map[seed_ind]}"

    for train_o_test in ['train', 'test']:

        if train_o_test == 'train':
            ddict, ldict = train_datasets, train_labels
        else: 
            ddict, ldict = test_datasets, test_labels

        for ind in range(n_task):
            fname = f"../{dataset_path}{file_suffix}/split_{train_o_test}_{ind}.pt"
            d, l = torch.load(fname)
            
            if dataset_name=="MNIST":
                d = d.type(torch.float)
                d = d.flatten(start_dim=1)
                

            if d.dtype is torch.uint8:
                # more efficient form of storage
                d = d.type(torch.float)/255

            d,l= d.numpy(), l.numpy()
            if min_max_scale:
                d = minmax_scale(d,axis=1)
            ddict[ind] = pd.DataFrame(d)
            
            unique_labels = np.sort(np.unique(l))
            # assuming there are always 2 per class here
            assert classes_per_split==2, "this code will not work otherwise."
            l1_mask = l==unique_labels[0]
            l2_mask = l==unique_labels[1]
            l[l1_mask]=(ind*2)
            l[l2_mask]=(ind*2)+1
            
            ldict[ind] = l
            
    return train_datasets, train_labels, test_datasets, test_labels

# %%
dataset_name = "CIFAR100"

n_kc = 1000#20000
#512
n_response = 32#32 #64 # approx 10% of the ORNs
seeds = [1,12,21,35,78]
thresh = 0

if dataset_name=="CIFAR100":
    n_orn = 256
    n_task = 50 #25
    seeds = seeds[:3]
    dataset_path=f"ConvMixerWTransforms_ImgNet32_{dataset_name}"
elif dataset_name=="CIFAR10":
    n_orn = 256
    n_task = 5
    dataset_path=f"ConvMixerWTransforms_ImgNet32_{dataset_name}"
elif dataset_name=="MNIST":
    n_orn = 784
    n_task = 5
    dataset_path=f"{dataset_name}"

lr = 0.01
classes_per_split = 2

min_max_scale = True

# %%
for seed_ind, seed in enumerate(seeds):
    #seed_ind=1
    train_datasets, train_labels, test_datasets, test_labels = load_my_dataset(seed_ind, min_max_scale=min_max_scale)
    R = generate_transformation_matrix(n_kc,n_orn,n_response,seed)
    accuracy = np.zeros([n_task, n_task])
    trained_weights = {}
    for i in range(n_task):
        trained_weights[i] = train(train_datasets[i], train_labels[i], lr, classes_per_split, i*classes_per_split)

        weights_to_test = np.concatenate([trained_weights[j] for j in range(i+1)])

        for j in range(i+1):
            # checking forgetting for each of them. 
            accuracy[i,j] = accu(weights_to_test,test_datasets[j],test_labels[j])

        print('loop '+str(i+1)+' done! accuracy here:', np.mean(accuracy[i,:]))
        
    accuracy = pd.DataFrame(accuracy)
    accuracy.to_csv(f'./accuracy/FlyModel_{dataset_name}_convMixer_lr_{lr}_randseed_{seed}_nkc={n_kc}_nresp={n_response}_minmax={min_max_scale}.csv',index=False,header=False)
    
    final_res = [np.mean(accuracy.iloc[i,:]) for i in range(n_task)]
    print(final_res)
    print('final performance', final_res[-1])
# Out:
# loop 1 done! accuracy here: 0.0182
# loop 2 done! accuracy here: 0.036399999999999995
# loop 3 done! accuracy here: 0.04739999999999999
# loop 4 done! accuracy here: 0.05859999999999999
# loop 5 done! accuracy here: 0.0749
# loop 6 done! accuracy here: 0.0825
# loop 7 done! accuracy here: 0.09570000000000001
# loop 8 done! accuracy here: 0.10259999999999998
# loop 9 done! accuracy here: 0.1131
# loop 10 done! accuracy here: 0.12079999999999998
# loop 11 done! accuracy here: 0.1318
# loop 12 done! accuracy here: 0.1434
# loop 13 done! accuracy here: 0.14990000000000003
# loop 14 done! accuracy here: 0.1563
# loop 15 done! accuracy here: 0.16390000000000002
# loop 16 done! accuracy here: 0.1727
# loop 17 done! accuracy here: 0.17770000000000002
# loop 18 done! accuracy here: 0.1833
# loop 19 done! accuracy here: 0.19200000000000003
# loop 20 done! accuracy here: 0.20009999999999997
# loop 21 done! accuracy here: 0.20809999999999998
# loop 22 done! accuracy here: 0.21109999999999998
# loop 23 done! accuracy here: 0.2131
# loop 24 done! accuracy here: 0.2186
# loop 25 done! accuracy here: 0.2278
# loop 26 done! accuracy here: 0.2304
# loop 27 done! accuracy here: 0.2398
# loop 28 done! accuracy here: 0.24530000000000002
# loop 29 done! accuracy here: 0.24960000000000002
# loop 30 done! accuracy here: 0.2559
# loop 31 done! accuracy here: 0.2657
# loop 32 done! accuracy here: 0.272
# loop 33 done! accuracy here: 0.2733
# loop 34 done! accuracy here: 0.278
# loop 35 done! accuracy here: 0.28740000000000004
# loop 36 done! accuracy here: 0.295
# loop 37 done! accuracy here: 0.2977
# loop 38 done! accuracy here: 0.30160000000000003
# loop 39 done! accuracy here: 0.30640000000000006
# loop 40 done! accuracy here: 0.3138
# loop 41 done! accuracy here: 0.317
# loop 42 done! accuracy here: 0.32370000000000004
# loop 43 done! accuracy here: 0.3281
# loop 44 done! accuracy here: 0.33569999999999994
# loop 45 done! accuracy here: 0.3415000000000001
# loop 46 done! accuracy here: 0.3458
# loop 47 done! accuracy here: 0.34769999999999995
# loop 48 done! accuracy here: 0.35480000000000006
# loop 49 done! accuracy here: 0.35780000000000006
# loop 50 done! accuracy here: 0.3612
# [0.0182, 0.036399999999999995, 0.04739999999999999, 0.05859999999999999, 0.0749, 0.0825, 0.09570000000000001, 0.1026, 0.1131, 0.12079999999999998, 0.1318, 0.14340000000000003, 0.14989999999999998, 0.1563, 0.16390000000000002, 0.1727, 0.17770000000000002, 0.18329999999999994, 0.192, 0.20009999999999997, 0.20810000000000003, 0.21109999999999998, 0.2131, 0.21860000000000002, 0.2278, 0.23040000000000002, 0.23980000000000004, 0.24529999999999996, 0.24960000000000002, 0.2558999999999999, 0.2656999999999999, 0.272, 0.27329999999999993, 0.27799999999999997, 0.28740000000000004, 0.29500000000000004, 0.2977, 0.30160000000000003, 0.30640000000000006, 0.31379999999999997, 0.31699999999999995, 0.3237, 0.3281, 0.3357, 0.3414999999999999, 0.3457999999999999, 0.3476999999999999, 0.35479999999999995, 0.3578, 0.36120000000000013]
# final performance 0.36120000000000013
# loop 1 done! accuracy here: 0.016399999999999998
# loop 2 done! accuracy here: 0.0301
# loop 3 done! accuracy here: 0.0463
# loop 4 done! accuracy here: 0.060899999999999996
# loop 5 done! accuracy here: 0.07189999999999999
# loop 6 done! accuracy here: 0.083
# loop 7 done! accuracy here: 0.0949
# loop 8 done! accuracy here: 0.1052
# loop 9 done! accuracy here: 0.1149
# loop 10 done! accuracy here: 0.11939999999999999
# loop 11 done! accuracy here: 0.1273
# loop 12 done! accuracy here: 0.1382
# loop 13 done! accuracy here: 0.1475
# loop 14 done! accuracy here: 0.1553
# loop 15 done! accuracy here: 0.1585
# loop 16 done! accuracy here: 0.16390000000000002
# loop 17 done! accuracy here: 0.17259999999999998
# loop 18 done! accuracy here: 0.17920000000000003
# loop 19 done! accuracy here: 0.1883
# loop 20 done! accuracy here: 0.1909
# loop 21 done! accuracy here: 0.1963
# loop 22 done! accuracy here: 0.1999
# loop 23 done! accuracy here: 0.20650000000000002
# loop 24 done! accuracy here: 0.2162
# loop 25 done! accuracy here: 0.22130000000000002
# loop 26 done! accuracy here: 0.23149999999999998
# loop 27 done! accuracy here: 0.239
# loop 28 done! accuracy here: 0.24630000000000002
# loop 29 done! accuracy here: 0.2498
# loop 30 done! accuracy here: 0.2547
# loop 31 done! accuracy here: 0.262
# loop 32 done! accuracy here: 0.26630000000000004
# loop 33 done! accuracy here: 0.27390000000000003
# loop 34 done! accuracy here: 0.28450000000000003
# loop 35 done! accuracy here: 0.2872
# loop 36 done! accuracy here: 0.2921
# loop 37 done! accuracy here: 0.29840000000000005
# loop 38 done! accuracy here: 0.3032
# loop 39 done! accuracy here: 0.3104
# loop 40 done! accuracy here: 0.3143
# loop 41 done! accuracy here: 0.3178
# loop 42 done! accuracy here: 0.32120000000000004
# loop 43 done! accuracy here: 0.32760000000000006
# loop 44 done! accuracy here: 0.332
# loop 45 done! accuracy here: 0.3386
# loop 46 done! accuracy here: 0.34340000000000004
# loop 47 done! accuracy here: 0.3446
# loop 48 done! accuracy here: 0.3539
# loop 49 done! accuracy here: 0.3564
# loop 50 done! accuracy here: 0.3619
# [0.016399999999999998, 0.0301, 0.0463, 0.060899999999999996, 0.07189999999999999, 0.083, 0.0949, 0.10520000000000002, 0.11489999999999999, 0.11939999999999998, 0.1273, 0.1382, 0.1475, 0.1553, 0.1585, 0.16390000000000002, 0.17259999999999995, 0.17919999999999997, 0.1883, 0.19090000000000007, 0.1963, 0.1999, 0.2065, 0.2162, 0.2213, 0.23149999999999998, 0.23899999999999996, 0.2463, 0.24979999999999994, 0.2547, 0.262, 0.2663, 0.2739, 0.2845, 0.2872, 0.29209999999999997, 0.2984, 0.30319999999999997, 0.3104, 0.3143, 0.3178, 0.3212000000000001, 0.32760000000000006, 0.332, 0.33860000000000007, 0.3434000000000001, 0.3446000000000001, 0.3539, 0.3564, 0.36190000000000005]
# final performance 0.36190000000000005
# loop 1 done! accuracy here: 0.0184
# loop 2 done! accuracy here: 0.0326
# loop 3 done! accuracy here: 0.046400000000000004
# loop 4 done! accuracy here: 0.055099999999999996
# loop 5 done! accuracy here: 0.0653
# loop 6 done! accuracy here: 0.0787
# loop 7 done! accuracy here: 0.09230000000000001
# loop 8 done! accuracy here: 0.1043
# loop 9 done! accuracy here: 0.1152
# loop 10 done! accuracy here: 0.12469999999999999
# loop 11 done! accuracy here: 0.1322
# loop 12 done! accuracy here: 0.1385
# loop 13 done! accuracy here: 0.1478
# loop 14 done! accuracy here: 0.1566
# loop 15 done! accuracy here: 0.16450000000000004
# loop 16 done! accuracy here: 0.1761
# loop 17 done! accuracy here: 0.18420000000000003
# loop 18 done! accuracy here: 0.19169999999999998
# loop 19 done! accuracy here: 0.1957
# loop 20 done! accuracy here: 0.2011
# loop 21 done! accuracy here: 0.21059999999999998
# loop 22 done! accuracy here: 0.21559999999999999
# loop 23 done! accuracy here: 0.2268
# loop 24 done! accuracy here: 0.2303
# loop 25 done! accuracy here: 0.2385
# loop 26 done! accuracy here: 0.24369999999999997
# loop 27 done! accuracy here: 0.2492
# loop 28 done! accuracy here: 0.25170000000000003
# loop 29 done! accuracy here: 0.2545
# loop 30 done! accuracy here: 0.25630000000000003
# loop 31 done! accuracy here: 0.2613
# loop 32 done! accuracy here: 0.26839999999999997
# loop 33 done! accuracy here: 0.27590000000000003
# loop 34 done! accuracy here: 0.27649999999999997
# loop 35 done! accuracy here: 0.28
# loop 36 done! accuracy here: 0.2847
# loop 37 done! accuracy here: 0.2915
# loop 38 done! accuracy here: 0.2959
# loop 39 done! accuracy here: 0.3038

# %%
dataset_name = "CIFAR10"

n_kc = 10000#20000
#512
n_response = 32#32 #64 # approx 10% of the ORNs
seeds = [1,12,21,35,78]

if dataset_name=="CIFAR100":
    n_orn = 256
    n_task = 50 #25
    dataset_path=f"ConvMixerWTransforms_ImgNet32_{dataset_name}"
    seeds = seeds[:3]
    nsteps = 500
    
elif dataset_name=="CIFAR10":
    n_orn = 256
    n_task = 5
    nsteps = 500
    dataset_path=f"ConvMixerWTransforms_ImgNet32_{dataset_name}"
elif dataset_name=="MNIST":
    n_orn = 784
    n_task = 5
    nsteps = None
    dataset_path=f"{dataset_name}"
    seeds = [seeds[0]]
    
print("Number of seeds", len(seeds))

lr = 0.01
classes_per_split = 2

min_max_scale = True

seed_accs = np.zeros([len(seeds), n_task])
t1_accs = np.zeros([len(seeds), n_task])
for sind, seed in enumerate(seeds):
    
    accuracy = pd.read_csv(f"accuracy/FlyModel_{dataset_name}_convMixer_lr_{lr}_randseed_{seed}_nkc={n_kc}_nresp={n_response}_minmax={min_max_scale}.csv",header=None)
    final_res = [np.mean(accuracy.iloc[i,:]) for i in range(n_task)]
    t1_accs[sind] = accuracy[0]
    print(final_res)
    print('final performance', final_res[-1])
    seed_accs[sind] = final_res
print("==========")
print(seed_accs.mean(axis=0))
print(seed_accs.mean(axis=0)[-1])
# Out:
# Number of seeds 5
# [0.197, 0.3709, 0.5105000000000001, 0.654, 0.8196999999999999]
# final performance 0.8196999999999999
# [0.1896, 0.36869999999999997, 0.5346, 0.6884, 0.8196999999999999]
# final performance 0.8196999999999999
# [0.18839999999999998, 0.36660000000000004, 0.5248, 0.6724, 0.8197000000000001]
# final performance 0.8197000000000001
# [0.1861, 0.3693, 0.5346, 0.6881, 0.8191]
# final performance 0.8191
# [0.1996, 0.37229999999999996, 0.5428999999999999, 0.6914, 0.8183999999999999]
# final performance 0.8183999999999999
# ==========
# [0.19214 0.36956 0.52948 0.67886 0.81932]
# 0.8193199999999999

# %%
source = seed_accs # t1_accs #seed_accs
mu = source.mean(axis=0)
std = source.std(axis=0)

line = []
std_line = []
for n in range(n_task):
    line += [mu[n]]*nsteps
    std_line += [std[n]]*nsteps
len(line)
# Out:
# 2500

# %%
mu
# Out:
# array([0.19214, 0.36956, 0.52948, 0.67886, 0.81932])

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.plot(np.arange(nsteps*n_task), line, linewidth=7)
plt.ylim(0,1.0)
plt.show()

# %%
fig = plt.gcf()
fig.set_size_inches(18.5, 10.5)
plt.errorbar(np.arange(nsteps*n_task), line, yerr=std_line)
plt.ylim(0,1.0)
plt.show()

# %%
# !ls accuracy/
# Out:
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_12_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_12_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_12_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_1_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_1_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_21_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_21_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_21_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_35_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_35_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_35_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_78_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_78_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR100_convMixer_lr_0.2_randseed_78_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.1_randseed_1_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_12_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_12_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_12_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_1_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_1_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_1_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_1_nkc=20000_nresp=64_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_21_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_21_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_21_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_35_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_35_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_35_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_78_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_78_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.2_randseed_78_nkc=1000_nresp=3_minmax=True.csv
# FlyModel_CIFAR10_convMixer_lr_0.4_randseed_1_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_MNIST_convMixer_lr_0.01_randseed_1_nkc=10000_nresp=32_minmax=True.csv
# FlyModel_MNIST_convMixer_lr_0.01_randseed_1_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_MNIST_convMixer_lr_0.1_randseed_1_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_MNIST_convMixer_lr_0.2_randseed_1_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_cifar100_convMixer_lr_0.2_randseed_1_nkc=1000_minmax=True.csv
# FlyModel_cifar100_convMixer_lr_0.2_randseed_1_nkc=1000_nresp=32_minmax=True.csv
# FlyModel_cifar100_resnet18_all_result_lr0.2_randseed_1.csv
# FlyModel_cifar100_resnet18_all_result_lr0.2_randseed_12.csv
# FlyModel_cifar100_resnet18_all_result_lr0.2_randseed_21.csv
# FlyModel_cifar100_resnet18_all_result_lr0.2_randseed_35.csv
# FlyModel_cifar100_resnet18_all_result_lr0.2_randseed_78.csv

# %%
[np.mean(df.iloc[i,:]) for i in range(n_task)]
# Out:
# [0.0197,
#  0.0387,
#  0.0541,
#  0.0709,
#  0.08929999999999999,
#  0.10220000000000001,
#  0.11969999999999999,
#  0.1335,
#  0.149,
#  0.16210000000000002,
#  0.177,
#  0.1919,
#  0.2027,
#  0.2155,
#  0.22800000000000004,
#  0.23980000000000004,
#  0.25190000000000007,
#  0.2602,
#  0.2723,
#  0.28550000000000003,
#  0.29730000000000006,
#  0.3089,
#  0.3146999999999999,
#  0.3235,
#  0.3379,
#  0.3453,
#  0.35730000000000006,
#  0.3678,
#  0.3761,
#  0.3863000000000001,
#  0.39710000000000006,
#  0.40840000000000004,
#  0.41489999999999994,
#  0.4247000000000001,
#  0.4396000000000001,
#  0.4488999999999999,
#  0.45360000000000006,
#  0.4610000000000001,
#  0.47290000000000015,
#  0.48470000000000013,
#  0.49250000000000005,
#  0.5043000000000001,
#  0.5146,
#  0.5262,
#  0.5382000000000001,
#  0.5499,
#  0.5549000000000001,
#  0.5669,
#  0.5731,
#  0.5801000000000001]

# %%
[np.mean(df.iloc[i,:i+1]) for i in range(n_task)]
# Out:
# [0.985,
#  0.9675,
#  0.9016666666666667,
#  0.88625,
#  0.893,
#  0.8516666666666667,
#  0.8549999999999999,
#  0.8343750000000001,
#  0.8277777777777778,
#  0.8105,
#  0.8045454545454546,
#  0.7995833333333332,
#  0.7796153846153846,
#  0.7696428571428572,
#  0.7600000000000001,
#  0.7493750000000001,
#  0.7408823529411767,
#  0.7227777777777777,
#  0.7165789473684211,
#  0.71375,
#  0.707857142857143,
#  0.7020454545454545,
#  0.6841304347826085,
#  0.6739583333333333,
#  0.6758,
#  0.6640384615384616,
#  0.6616666666666667,
#  0.6567857142857143,
#  0.648448275862069,
#  0.6438333333333335,
#  0.6404838709677421,
#  0.638125,
#  0.6286363636363635,
#  0.6245588235294118,
#  0.6280000000000001,
#  0.6234722222222221,
#  0.612972972972973,
#  0.6065789473684212,
#  0.6062820512820515,
#  0.6058750000000002,
#  0.6006097560975611,
#  0.6003571428571429,
#  0.5983720930232558,
#  0.5979545454545455,
#  0.5980000000000001,
#  0.597717391304348,
#  0.5903191489361703,
#  0.5905208333333333,
#  0.584795918367347,
#  0.5801000000000001]
