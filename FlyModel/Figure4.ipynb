# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
import seaborn as sns
from matplotlib import pylab as PP
import itertools

plt.style.use('ggplot') # change to ggplot style.
PP.rc('font', **{'sans-serif':'Arial', 'family':'sans-serif'}) # Uses Arial font for all.

# %% [markdown]
# ## CIFAR-100
# ### Finding the best parameters for perceptron v1 - v4

# %%
v11 = pd.read_csv('./accuracy/Perceptron_v1_cifar100_resnet18_all_result_lr_2.csv',header=None)
v12 = pd.read_csv('./accuracy/Perceptron_v1_cifar100_resnet18_all_result_lr_1.csv',header=None)
v13 = pd.read_csv('./accuracy/Perceptron_v1_cifar100_resnet18_all_result_lr_0.5.csv',header=None)
v14 = pd.read_csv('./accuracy/Perceptron_v1_cifar100_resnet18_all_result_lr_0.2.csv',header=None)
v15 = pd.read_csv('./accuracy/Perceptron_v1_cifar100_resnet18_all_result_lr_0.1.csv',header=None)
v16 = pd.read_csv('./accuracy/Perceptron_v1_cifar100_resnet18_all_result_lr_0.01.csv',header=None)

# %%
n = v11.shape[0]
v1_1 = [np.mean(v11.iloc[i,:i+1]) for i in range(n)]
v1_2 = [np.mean(v12.iloc[i,:i+1]) for i in range(n)]
v1_3 = [np.mean(v13.iloc[i,:i+1]) for i in range(n)]
v1_4 = [np.mean(v14.iloc[i,:i+1]) for i in range(n)]
v1_5 = [np.mean(v15.iloc[i,:i+1]) for i in range(n)]
v1_6 = [np.mean(v16.iloc[i,:i+1]) for i in range(n)]

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,26))*4
plt.plot(x, v1_1,color='blue',label='lr=2',marker='.');
plt.plot(x, v1_2,color='red',label='lr=1',marker='<');
plt.plot(x, v1_3,color='black',label='lr=0.5',marker='s');
plt.plot(x, v1_4,color='green',label='lr=0.2',marker='*');
plt.plot(x, v1_5,color='cyan',label='lr=0.1',marker='+');
plt.plot(x, v1_6,color='pink',label='lr=0.01',marker='>');
plt.title('V1',size=20);
plt.legend(loc='best',fontsize=14);
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
v21 = pd.read_csv('./accuracy/Perceptron_v2_cifar100_resnet18_all_result_lr_2.csv',header=None)
v22 = pd.read_csv('./accuracy/Perceptron_v2_cifar100_resnet18_all_result_lr_1.csv',header=None)
v23 = pd.read_csv('./accuracy/Perceptron_v2_cifar100_resnet18_all_result_lr_0.5.csv',header=None)
v24 = pd.read_csv('./accuracy/Perceptron_v2_cifar100_resnet18_all_result_lr_0.2.csv',header=None)
v25 = pd.read_csv('./accuracy/Perceptron_v2_cifar100_resnet18_all_result_lr_0.1.csv',header=None)
v26 = pd.read_csv('./accuracy/Perceptron_v2_cifar100_resnet18_all_result_lr_0.01.csv',header=None)

# %%
n = v21.shape[0]
v2_1 = [np.mean(v21.iloc[i,:i+1]) for i in range(n)]
v2_2 = [np.mean(v22.iloc[i,:i+1]) for i in range(n)]
v2_3 = [np.mean(v23.iloc[i,:i+1]) for i in range(n)]
v2_4 = [np.mean(v24.iloc[i,:i+1]) for i in range(n)]
v2_5 = [np.mean(v25.iloc[i,:i+1]) for i in range(n)]
v2_6 = [np.mean(v26.iloc[i,:i+1]) for i in range(n)]

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,26))*4
plt.plot(x, v2_1,color='blue',label='lr=2',marker='.');
plt.plot(x, v2_2,color='red',label='lr=1',marker='<');
plt.plot(x, v2_3,color='black',label='lr=0.5',marker='s');
plt.plot(x, v2_4,color='green',label='lr=0.2',marker='*');
plt.plot(x, v2_5,color='cyan',label='lr=0.1',marker='+');
plt.plot(x, v2_6,color='pink',label='lr=0.01',marker='>');
plt.title('V2',size=20);
plt.legend(loc='best',fontsize=14);

# %%
v31 = pd.read_csv('./accuracy/Perceptron_v3_cifar100_resnet18_all_result_lr_1.csv',header=None)
v32 = pd.read_csv('./accuracy/Perceptron_v3_cifar100_resnet18_all_result_lr_0.5.csv',header=None)
v33 = pd.read_csv('./accuracy/Perceptron_v3_cifar100_resnet18_all_result_lr_0.2.csv',header=None)
v34 = pd.read_csv('./accuracy/Perceptron_v3_cifar100_resnet18_all_result_lr_0.1.csv',header=None)
v35 = pd.read_csv('./accuracy/Perceptron_v3_cifar100_resnet18_all_result_lr_0.01.csv',header=None)
v36 = pd.read_csv('./accuracy/Perceptron_v3_cifar100_resnet18_all_result_lr_0.001.csv',header=None)

# %%
n = v31.shape[0]
v3_1 = [np.mean(v31.iloc[i,:i+1]) for i in range(n)]
v3_2 = [np.mean(v32.iloc[i,:i+1]) for i in range(n)]
v3_3 = [np.mean(v33.iloc[i,:i+1]) for i in range(n)]
v3_4 = [np.mean(v34.iloc[i,:i+1]) for i in range(n)]
v3_5 = [np.mean(v35.iloc[i,:i+1]) for i in range(n)]
v3_6 = [np.mean(v36.iloc[i,:i+1]) for i in range(n)]

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,26))*4
plt.plot(x, v3_1,color='blue',label='lr=1',marker='.');
plt.plot(x, v3_2,color='red',label='lr=0.5',marker='<');
plt.plot(x, v3_3,color='black',label='lr=0.2',marker='s');
plt.plot(x, v3_4,color='green',label='lr=0.1',marker='*');
plt.plot(x, v3_5,color='cyan',label='lr=0.01',marker='+');
plt.plot(x, v3_6,color='pink',label='lr=0.001',marker='>');
plt.title('V3',size=20);
plt.legend(loc='best',fontsize=14);

# %%
v41 = pd.read_csv('./accuracy/Perceptron_v4_cifar100_resnet18_all_result_lr_1.csv',header=None)
v42 = pd.read_csv('./accuracy/Perceptron_v4_cifar100_resnet18_all_result_lr_0.5.csv',header=None)
v43 = pd.read_csv('./accuracy/Perceptron_v4_cifar100_resnet18_all_result_lr_0.2.csv',header=None)
v44 = pd.read_csv('./accuracy/Perceptron_v4_cifar100_resnet18_all_result_lr_0.1.csv',header=None)
v45 = pd.read_csv('./accuracy/Perceptron_v4_cifar100_resnet18_all_result_lr_0.01.csv',header=None)
v46 = pd.read_csv('./accuracy/Perceptron_v4_cifar100_resnet18_all_result_lr_0.001.csv',header=None)

# %%
n = v41.shape[0]
v4_1 = [np.mean(v41.iloc[i,:i+1]) for i in range(n)]
v4_2 = [np.mean(v42.iloc[i,:i+1]) for i in range(n)]
v4_3 = [np.mean(v43.iloc[i,:i+1]) for i in range(n)]
v4_4 = [np.mean(v44.iloc[i,:i+1]) for i in range(n)]
v4_5 = [np.mean(v45.iloc[i,:i+1]) for i in range(n)]
v4_6 = [np.mean(v46.iloc[i,:i+1]) for i in range(n)]

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,26))*4
plt.plot(x, v4_1,color='blue',label='lr=1',marker='.');
plt.plot(x, v4_2,color='red',label='lr=0.5',marker='<');
plt.plot(x, v4_3,color='black',label='lr=0.2',marker='s');
plt.plot(x, v4_4,color='green',label='lr=0.1',marker='*');
plt.plot(x, v4_5,color='cyan',label='lr=0.01',marker='+');
plt.plot(x, v4_6,color='pink',label='lr=0.001',marker='>');
plt.title('V4',size=20);
plt.legend(loc='best',fontsize=14);

# %% [markdown]
# ### Compare perceptron v1 - v4

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,26))*4

plt.plot(x, v4_4,color='#e63946',label='Perceptron V4',marker='o',lw=2);
plt.plot(x, v3_5,color='#a14a76',label='Perceptron V3',marker='.',lw=2);
plt.plot(x, v2_4,color='#38040e',label='Perceptron V2',marker='<',lw=2);
plt.plot(x, v1_3,color='#ffa5ab',label='Perceptron V1',marker='s',lw=2);

plt.xlabel('Number of Trained Classes',size=16,color='black');
plt.ylabel('Accuracy of Trained Classes',size=16,color='black');
plt.xticks((np.arange(0, 101, step=10)), size=14, color='black');
plt.yticks(size=14, color='black');
plt.ylim(0,1.05);
#plt.title('CIFAR-100', fontsize=22);
#plt.legend(loc='best',fontsize=14);
plt.savefig('../figures/Fig_4B.png',dpi=512);
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## MNIST20
# ### Finding the best parameters

# %%
pv11 = pd.read_csv('./accuracy/Sparse-coding_v1_lr2.csv',header=None)
pv12 = pd.read_csv('./accuracy/Sparse-coding_v1_lr1.csv',header=None)
pv13 = pd.read_csv('./accuracy/Sparse-coding_v1_lr0.1.csv',header=None)
pv14 = pd.read_csv('./accuracy/Sparse-coding_v1_lr0.01.csv',header=None)

# %%
n = pv11.shape[0]
pv1_1 = [np.mean(pv11.iloc[i,:i+1]) for i in range(n)]
pv1_2 = [np.mean(pv12.iloc[i,:i+1]) for i in range(n)]
pv1_3 = [np.mean(pv13.iloc[i,:i+1]) for i in range(n)]
pv1_4 = [np.mean(pv14.iloc[i,:i+1]) for i in range(n)]

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,11))*2
plt.plot(x, pv1_1,color='blue',label='lr=2',marker='.');
plt.plot(x, pv1_2,color='red',label='lr=1',marker='<');
plt.plot(x, pv1_3,color='black',label='lr=0.1',marker='s');
plt.plot(x, pv1_4,color='green',label='lr=0.01',marker='*');
plt.title('V1',size=20);
plt.legend(loc='best',fontsize=14);

# %%
pv21 = pd.read_csv('./accuracy/Sparse-coding_v2_lr2.csv',header=None)
pv22 = pd.read_csv('./accuracy/Sparse-coding_v2_lr1.csv',header=None)
pv23 = pd.read_csv('./accuracy/Sparse-coding_v2_lr0.1.csv',header=None)
pv24 = pd.read_csv('./accuracy/Sparse-coding_v2_lr0.01.csv',header=None)

# %%
n = pv21.shape[0]
pv2_1 = [np.mean(pv21.iloc[i,:i+1]) for i in range(n)]
pv2_2 = [np.mean(pv22.iloc[i,:i+1]) for i in range(n)]
pv2_3 = [np.mean(pv23.iloc[i,:i+1]) for i in range(n)]
pv2_4 = [np.mean(pv24.iloc[i,:i+1]) for i in range(n)]

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,11))*2
plt.plot(x, pv2_1,color='blue',label='lr=2',marker='.');
plt.plot(x, pv2_2,color='red',label='lr=1',marker='<');
plt.plot(x, pv2_3,color='black',label='lr=0.1',marker='s');
plt.plot(x, pv2_4,color='green',label='lr=0.01',marker='*');
plt.title('V2',size=20);
plt.legend(loc='best',fontsize=14);

# %%
pv31 = pd.read_csv('./accuracy/Sparse-coding_v3_lr0.1.csv',header=None)
pv32 = pd.read_csv('./accuracy/Sparse-coding_v3_lr0.01.csv',header=None)
pv33 = pd.read_csv('./accuracy/Sparse-coding_v3_lr0.001.csv',header=None)
pv34 = pd.read_csv('./accuracy/Sparse-coding_v3_lr0.0001.csv',header=None)

# %%
n = pv31.shape[0]
pv3_1 = [np.mean(pv31.iloc[i,:i+1]) for i in range(n)]
pv3_2 = [np.mean(pv32.iloc[i,:i+1]) for i in range(n)]
pv3_3 = [np.mean(pv33.iloc[i,:i+1]) for i in range(n)]
pv3_4 = [np.mean(pv34.iloc[i,:i+1]) for i in range(n)]

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,11))*2
plt.plot(x, pv3_1,color='blue',label='lr=0.1',marker='.');
plt.plot(x, pv3_2,color='red',label='lr=0.01',marker='<');
plt.plot(x, pv3_3,color='black',label='lr=0.001',marker='s');
plt.plot(x, pv3_4,color='green',label='lr=0.0001',marker='*');
plt.title('V3',size=20);
plt.legend(loc='best',fontsize=14);

# %%
pv41 = pd.read_csv('./accuracy/Sparse-coding_v4_lr0.1.csv',header=None)
pv42 = pd.read_csv('./accuracy/Sparse-coding_v4_lr0.01.csv',header=None)
pv43 = pd.read_csv('./accuracy/Sparse-coding_v4_lr0.001.csv',header=None)
pv44 = pd.read_csv('./accuracy/Sparse-coding_v4_lr0.0001.csv',header=None)

# %%
n = pv41.shape[0]
pv4_1 = [np.mean(pv41.iloc[i,:i+1]) for i in range(n)]
pv4_2 = [np.mean(pv42.iloc[i,:i+1]) for i in range(n)]
pv4_3 = [np.mean(pv43.iloc[i,:i+1]) for i in range(n)]
pv4_4 = [np.mean(pv44.iloc[i,:i+1]) for i in range(n)]

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,11))*2
plt.plot(x, pv4_1,color='blue',label='lr=0.1',marker='.');
plt.plot(x, pv4_2,color='red',label='lr=0.01',marker='<');
plt.plot(x, pv4_3,color='black',label='lr=0.001',marker='s');
plt.plot(x, pv4_4,color='green',label='lr=0.0001',marker='*');
plt.title('V4',size=20);
plt.legend(loc='best',fontsize=14);

# %% [markdown]
# ### Compare

# %%
plt.figure(figsize=(7,5))
x = np.array(range(1,11))*2

plt.plot(x, pv4_2,color='#e63946',label='Perceptron V4 (FlyModel)',marker='o',lw=2);
plt.plot(x, pv3_3,color='#a14a76',label='Perceptron V3',marker='.',lw=2);
plt.plot(x, pv2_1,color='#38040e',label='Perceptron V2',marker='<',lw=2);
plt.plot(x, pv1_3,color='#ffa5ab',label='Perceptron V1 (Classic)',marker='s',lw=2);

plt.xlabel('Number of Trained Classes',size=16,color='black');
plt.ylabel('Accuracy of Trained Classes',size=16,color='black');
plt.xticks((np.arange(2, 21, step=2)), size=14, color='black');
plt.yticks(size=14, color='black');
plt.ylim(-0.11,1.05);
#plt.title('MNIST-20', fontsize=22);
plt.legend(loc='best',fontsize=14);
plt.savefig('../figures/Fig_4A.png',dpi=512);
